# %%
# 清空内核状态
# %reset -f

# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import torch.nn as nn
import torch.optim as optim
import numpy as np
import math

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
setup_seed(123456)

# %%
#要设置的参数
Ex=0#E也要放小e6倍，这里是0就不放了
Ey=0
Ez=0#托卡马克里面没电场
B0=5#磁轴中心的磁感应强度为5T
q=2.5#安全因子，注意，不是电荷
R0=6.2#托卡马克大半径6.2m
q_over_m = 4.822452834e1  # 电荷与质量之比

#单位问题：跑太大的数，程序吃不消，得归一化。几个大数，q_over_m = 4.8e7，vx0vy0 1e6 5e6，interval 4.1473e-9，要动
#程序中，要让轨迹相对形状不变，又因为B和位置有关，所以轨迹数值也不能变
#a=q/m（E+vB），x=vt+0.5at^2
#让位移x=vt+0.5at^2不变，让interval扩大e6倍，让v缩小e6倍(让v0和x0在同一量级，这样好训练)，让q_over_m缩小e6倍，E也要放小e6倍，这样a放小e12个
def Bx(x,y,z):
    return B0/q*(-q*R0*y+z*x)/(x**2+y**2)
def By(x,y,z):
    return B0/q*(q*R0*x+z*y)/(x**2+y**2)
def Bz(x,y,z):
    return B0/q*(-1+R0/(x**2+y**2)**0.5)
    

target_x0=torch.tensor([7.2])
target_y0=torch.tensor([0.0])
target_z0=torch.tensor([0.0])
target_vx0=torch.tensor([1.0])
target_vy0=torch.tensor([5.0])#这里是通行α粒子数据
target_vz0=torch.tensor([0.0])


interval=4.147267104135095e-4#根据学长给的数据取值,e-3是小圈的1/2π,e-4就是小圈的60分之一，更精确
#总运动时间是n*interval
learning_rate=2e-3

stop_condition = 5e-4#停止训练的loss值要求


#设置初始权重
lamda1=1#lpde权重
lamda2=400#lE权重
lamda3=600#l0权重

# %%
n=50#训练中的t共n个时间点,注意画三维图的点不建议超过200个，容易炸内核
n_all=10000#总覆盖时间点数，绘图用
jump=0#单位是interval
n_epoch=10#每几次epoch就计数

n_test=50#在n_all范围内，等距取多少个test点
new_prefix = "8.2.changsui"  # 新的文件名前缀

# %%
#Neural Network
#t作为输入，x,y,z作为输出，中间三个隐藏层
#MLP是最基础的全连接神经网络

class SinActivation(torch.nn.Module):
    def __init__(self):
        super(SinActivation, self).__init__()
        self.a = nn.Parameter(torch.tensor(0.1))  # 将a设置为可学习的参数

    def forward(self, x):
        return torch.sin(self.a *10* x)

class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP,self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(1,128),#0层
            SinActivation(),#1层
            torch.nn.Linear(128,128),#2层
            SinActivation(),#3
            torch.nn.Linear(128,128),#4
            SinActivation(),#5
            torch.nn.Linear(128,128),#6
            SinActivation(),#7
            torch.nn.Linear(128,3),#8
        )
         # 对每个线性层进行Glorot初始化
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
    def forward(self,x):
        return self.net(x)
    
    
u = MLP()  # 网络名称

# %%
# import torch
# #from ceshi_Copy1 import MLP  # 导入你的模型类定义

# # 创建模型实例
# # u = MyModel()

# # 加载模型参数
# u.load_state_dict(torch.load('3.1.1保存.pth'))

# # 设置模型为评估模式（如果只是进行推理）
# # u.eval()

# %%
#下面是求导
def gradients(x,t,order=1):
    if order == 1:
        return torch.autograd.grad(x,t,grad_outputs=torch.ones_like(x),#用于计算某个标量相对于一组输入张量的梯度
                                  create_graph = True,
                                  only_inputs=True,)[0]#create_graph： 这是一个布尔值，如果设置为 True，则创建一个用于计算更高阶梯度的计算图。
                                                    #这对于执行高阶梯度的操作是有用的。在训练深度学习模型时，可能需要计算模型参数的二阶梯度。
    else:
        return gradients(gradients(x,t),t,order = order-1)#二阶及以上导

# %%
#损失函数
#LOSS
loss = torch.nn.MSELoss()
tensortarget = (target_vx0**2+target_vy0**2+target_vz0**2)**0.5*0.98
target_initial = tensortarget.repeat(n+1).view(-1, 1)#保能量项用的

def funcmiu(x,y,z,vx,vy,vz):
    miu=(vx**2+vy**2+vz**2)/(Bx(x,y,z)**2+By(x,y,z)**2+Bz(x,y,z)**2)**0.5-(vx*Bx(x,y,z)+vy*By(x,y,z)+vz*Bz(x,y,z))**2/(Bx(x,y,z)**2+By(x,y,z)**2+Bz(x,y,z)**2)**1.5
    return miu


def LOSS(u):
    
    samples = torch.arange(jump*interval, (n_all+1+jump)*interval, step=int(n_all/n)*interval)+torch.rand(n+1) * interval*int(n_all/n)*1   #random jitter to samples 10%#实际上n+1个点
    t = samples.view(-1, 1).requires_grad_(True)
    x = u(t)[:, 0].view(-1, 1)
    y = u(t)[:, 1].view(-1, 1)
    z = u(t)[:, 2].view(-1, 1)
    vx = gradients(x, t, 1)
    vy = gradients(y, t, 1)
    vz = gradients(z, t, 1)

    lpde1 = loss(gradients(vx, t, 1), q_over_m*(Ex + vy * Bz(x,y,z) - vz * By(x,y,z)))
    lpde2 = loss(gradients(vy, t, 1), q_over_m*(Ey + vz * Bx(x,y,z) - vx * Bz(x,y,z)))
    lpde3 = loss(gradients(vz, t, 1), q_over_m*(Ez + vx * By(x,y,z) - vy * Bx(x,y,z)))

    lE = loss((vx**2+vy**2+vz**2)**0.5,target_initial)
    miu=funcmiu(x,y,z,vx,vy,vz)
    lpde = lpde1 + lpde2 + lpde3 

    t0=torch.tensor([0.0]).requires_grad_(True)
    l00=(u(t0)[0] - target_x0)**2
    l01=(u(t0)[1] - target_y0)**2
    l02=(u(t0)[2] - target_z0)**2
    l03=(gradients(u(t0)[0],t0,1) - target_vx0)**2
    l04=(gradients(u(t0)[1],t0,1) - target_vy0)**2
    l05=(gradients(u(t0)[2],t0,1) - target_vz0)**2
    l0=l00+l01+l02+l03+l04+l05

    return lpde,lE,l0

# %%
opt = torch.optim.Adam(u.parameters(), lr=learning_rate)
def funcweight(lpde):
    lpde.backward(retain_graph=True)#初态只对第0层的weight的梯度才全是0，其他情况都有梯度
    # 获取网络的参数列表
    gradientlw0 = u.net[0].weight.grad.clone()
    gradientlb0 = u.net[0].bias.grad.clone()
    gradientlw2 = u.net[2].weight.grad.clone()
    gradientlb2 = u.net[2].bias.grad.clone()
    gradientlw4 = u.net[4].weight.grad.clone()
    gradientlb4 = u.net[4].bias.grad.clone()
    gradientlw6 = u.net[6].weight.grad.clone()
    gradientlb6 = u.net[6].bias.grad.clone()
    gradientlw8 = u.net[8].weight.grad.clone()
    gradientlb8 = u.net[8].bias.grad.clone()
    opt.zero_grad()
    tensors_l = [gradientlw0,gradientlb0,gradientlw2,gradientlb2,gradientlw4,gradientlb4,gradientlw6,gradientlb6,
                gradientlw8,gradientlb8]
    squared_sums = [torch.sum(tensor ** 2) for tensor in tensors_l]
    # 将所有平方和相加
    total_squared_sum = sum(squared_sums)
    l2_norm_gradient_l=(total_squared_sum.item())**0.5
    return l2_norm_gradient_l

# %%
# 加载文本文件
xdata = np.loadtxt('通行x_real.txt')
# 从第四个数据开始，每隔10个数据读取一个，共读取50个数据
xselected_data = xdata[jump::int(n_all/n_test)][:(n_test+1)]
# 将所选数据转换为PyTorch张量
x_real = torch.tensor(xselected_data, dtype=torch.float32).view(-1,1)

ydata = np.loadtxt('通行y_real.txt')
yselected_data = ydata[jump::int(n_all/n_test)][:(n_test+1)]
y_real = torch.tensor(yselected_data, dtype=torch.float32).view(-1,1)

zdata = np.loadtxt('通行z_real.txt')
zselected_data = zdata[jump::int(n_all/n_test)][:(n_test+1)]
z_real = torch.tensor(zselected_data, dtype=torch.float32).view(-1,1)



#全500点，用于后续绘图
x_plt=xdata[jump:(n_all+1+jump):1]
y_plt=ydata[jump:(n_all+1+jump):1]
z_plt=zdata[jump:(n_all+1+jump):1]
x_real_plt=torch.tensor(x_plt, dtype=torch.float32).view(-1,1)#真实值的0~500点，
y_real_plt=torch.tensor(y_plt, dtype=torch.float32).view(-1,1)
z_real_plt=torch.tensor(z_plt, dtype=torch.float32).view(-1,1)
vxdata = (np.loadtxt('通行vx_real.txt'))*1e-6
vydata = (np.loadtxt('通行vy_real.txt'))*1e-6
vzdata = (np.loadtxt('通行vz_real.txt'))*1e-6
vx_real_plt=torch.tensor(vxdata[jump:(n_all+1+jump):1], dtype=torch.float32).view(-1,1)
vy_real_plt=torch.tensor(vydata[jump:(n_all+1+jump):1], dtype=torch.float32).view(-1,1)
vz_real_plt=torch.tensor(vzdata[jump:(n_all+1+jump):1], dtype=torch.float32).view(-1,1)
xdata=[]
ydata=[]
zdata=[]
vxdata=[]
vydata=[]
vzdata=[]#清空这二百四十万个数据

#x_real：用于训练过程神经网络输出值与真实值对比，3，13,23…493共50个时刻点，对应t_test
#x_real_plt：用于绘制真实图，0~500全点

# %%
#训练过程中记录的量
loss_list=[]#总损失，带权重
lpde_list=[]#方程项损失
l0_list=[]#初态损失
lE_list=[]#能量项损失loss，也是与真实能量做对比diff
lamda1_list=[]#方程项权重，把保能量保磁矩也放在这一项
lamda2_list=[]#能量项权重
lamda3_list=[]#初态权重
l_withoutweight_list=[]#总损失，不带权重
time_list=[]#训练时间记录
loss_test_list=[]#部分时刻点，输出位置与真实位置误差向量的模平方，即位置与真实值的误差
lossmean_test_list=[]#部分时刻点，输出位置与真实位置误差的算术平均值，(sigma（xn+yn+zn）-sigma(xc+yc+zc))/n ,证明轨迹可以视为导心
miu_train_list=[]

# %%
import time
start_time = time.time()#计时
epochs = 4000  #训练次数
opt = torch.optim.Adam(u.parameters(), lr=learning_rate)

for i in range(epochs):
    opt.zero_grad()
    
    lpde=LOSS(u)[0]
    lE=LOSS(u)[1]
    l0=LOSS(u)[2]
  
    if (i+1)%1000== 0:
        gradient_lpde=funcweight(lpde)
        gradient_lE=funcweight(lE)
        gradient_l0=funcweight(l0) 

    if (i+1)%1000== 0 and lpde>1e-5:
        lamda1=0.2*lamda1+0.8*(  (gradient_lpde+gradient_l0+gradient_lE)/gradient_lpde  )
    if (i+1)%1000== 0 and l0>1e-5:
        lamda3=0.2*lamda3+0.8*(  (gradient_lpde+gradient_l0+gradient_lE)/gradient_l0  )
    if (i+1)%1000== 0 and lE>1e-5:
        lamda2=0.2*lamda2+0.8*(  (gradient_lpde+gradient_l0+gradient_lE)/gradient_lE  )
        
    l_total=lamda1*lpde+lamda3*l0*5+lamda2*lE
    l_withoutweight=lpde+l0+lE
    l_total.backward()
    opt.step()
    
    
    if (i+1)%200 == 0:
        learnr = opt.param_groups[0]['lr']
        
        #更新学习率
        learning_rate *=0.5
        for param_group in opt.param_groups:
            param_group['lr'] = learning_rate
    
    
    

    if (i+1)%n_epoch == 0 or i==0:
        end_time = time.time()
        total_time = end_time - start_time
        learnr = opt.param_groups[0]['lr']
        time_test =torch.arange(interval*jump, interval*(n_all+1+jump), interval*int(n_all/n_test))
        t_test = time_test.view(-1, 1).requires_grad_(True)
        x_test = u(t_test)[:, 0].view(-1, 1)
        y_test = u(t_test)[:, 1].view(-1, 1)
        z_test = u(t_test)[:, 2].view(-1, 1)
        vx_test = gradients(x_test,t_test,1)
        vy_test = gradients(y_test,t_test,1)
        vz_test = gradients(z_test,t_test,1)
        loss_test = loss(x_test,x_real)+loss(y_test,y_real)+loss(z_test,z_real)
        miu_train=funcmiu(x_test,y_test,z_test,vx_test,vy_test,vz_test)
        #lcq=lE+lmiu_test#注意这里！！
        lossmean_test = torch.sum(x_test-x_real+y_test-y_real+z_test-z_real)/n
        print(f'Epoch [{i+1}/{epochs}], Loss: {l_total.item():.4g},   LOSS_function: {lpde.item():.4g},   LOSS_E:{lE.item():.4g},    LOSS_initial: {l0.item():.4g},')
        print(f'lamda1:{lamda1:.4g},    lamda2:{lamda2:.4g},    lamda3:{lamda3:.4g},      learn rate:{learnr:.4g},    time: {total_time}' )
        print(f'loss_compared with real:{loss_test:.5g},   miu_train:{miu_train.mean():.4g},    lossmean:{lossmean_test.item():.4g}') 
        loss_list.append(l_total.item())
        lpde_list.append(lpde.item())
        l0_list.append(l0.item())
        lE_list.append(lE.item())
        lamda1_list.append(lamda1)
        lamda2_list.append(lamda2)
        lamda3_list.append(lamda3)
        l_withoutweight_list.append(l_withoutweight.item())
        time_list.append(total_time)
        loss_test_list.append(loss_test.item())
        lossmean_test_list.append(lossmean_test.item())
        miu_train_list.append(miu_train.mean())
    
    if (i+1)%4000 == 0:
        for name, param in u.named_parameters():
            if 'a' in name:  # 筛选出包含'a'的参数
                print(name, param)
        
        
    if l_total <= stop_condition:#刚才写成loss_test了，感觉不妥，毕竟应该不知道真实数字是多少
        print(f'Training stopped at No.{i+1} time. Loss ({l_total}) is below the specified threshold ({stop_condition}).')
        break
# Out:
# Epoch [1/4000], Loss: 3.414e+05,   LOSS_function: 1.28e+05,   LOSS_E:23.34,    LOSS_initial: 68.01,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 0.0663747787475586
# loss_compared with real:55.066,   miu_train:0.01189,    lossmean:-0.8319
# Epoch [10/4000], Loss: 7.587e+04,   LOSS_function: 552.3,   LOSS_E:20.67,    LOSS_initial: 22.35,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 0.6292500495910645
# loss_compared with real:97.734,   miu_train:0.006889,    lossmean:4.456
# Epoch [20/4000], Loss: 3.306e+04,   LOSS_function: 1530,   LOSS_E:15.36,    LOSS_initial: 8.461,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 1.2494370937347412
# loss_compared with real:62.383,   miu_train:0.0119,    lossmean:5.446
# Epoch [30/4000], Loss: 9855,   LOSS_function: 885.3,   LOSS_E:12.49,    LOSS_initial: 1.325,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 1.8726232051849365
# loss_compared with real:39.257,   miu_train:0.00232,    lossmean:5.085
# Epoch [40/4000], Loss: 7123,   LOSS_function: 1476,   LOSS_E:11.21,    LOSS_initial: 0.388,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 2.48803448677063
# loss_compared with real:35.087,   miu_train:0.008351,    lossmean:5.585
# Epoch [50/4000], Loss: 5328,   LOSS_function: 596.8,   LOSS_E:9.92,    LOSS_initial: 0.2544,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 3.1192357540130615
# loss_compared with real:29.479,   miu_train:0.004244,    lossmean:4.764
# Epoch [60/4000], Loss: 4401,   LOSS_function: 638.9,   LOSS_E:8.32,    LOSS_initial: 0.1448,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 3.745412826538086
# loss_compared with real:25.671,   miu_train:0.003958,    lossmean:4.65
# Epoch [70/4000], Loss: 3731,   LOSS_function: 443.5,   LOSS_E:6.757,    LOSS_initial: 0.1948,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 4.38470196723938
# loss_compared with real:21.268,   miu_train:0.004139,    lossmean:4.237
# Epoch [80/4000], Loss: 3199,   LOSS_function: 545.9,   LOSS_E:5.712,    LOSS_initial: 0.1226,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 5.0035319328308105
# loss_compared with real:16.122,   miu_train:0.00394,    lossmean:3.769
# Epoch [90/4000], Loss: 2642,   LOSS_function: 468.5,   LOSS_E:4.477,    LOSS_initial: 0.1276,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 5.635524272918701
# loss_compared with real:12.451,   miu_train:0.003274,    lossmean:3.384
# Epoch [100/4000], Loss: 2111,   LOSS_function: 344.6,   LOSS_E:3.437,    LOSS_initial: 0.1305,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 6.292215585708618
# loss_compared with real:9.5973,   miu_train:0.003381,    lossmean:2.944
# Epoch [110/4000], Loss: 1710,   LOSS_function: 406.5,   LOSS_E:2.418,    LOSS_initial: 0.1121,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 6.950405120849609
# loss_compared with real:7.5676,   miu_train:0.003702,    lossmean:2.651
# Epoch [120/4000], Loss: 1469,   LOSS_function: 410.1,   LOSS_E:1.69,    LOSS_initial: 0.1278,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 7.59409761428833
# loss_compared with real:5.6787,   miu_train:0.003251,    lossmean:2.304
# Epoch [130/4000], Loss: 1043,   LOSS_function: 348.9,   LOSS_E:1.133,    LOSS_initial: 0.0804,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 8.22394847869873
# loss_compared with real:3.7927,   miu_train:0.004387,    lossmean:1.919
# Epoch [140/4000], Loss: 1212,   LOSS_function: 577.2,   LOSS_E:0.7622,    LOSS_initial: 0.1098,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 8.855123043060303
# loss_compared with real:2.2118,   miu_train:0.003844,    lossmean:1.465
# Epoch [150/4000], Loss: 1462,   LOSS_function: 1037,   LOSS_E:0.5732,    LOSS_initial: 0.0651,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 9.506839036941528
# loss_compared with real:2.8247,   miu_train:0.005139,    lossmean:1.708
# Epoch [160/4000], Loss: 774.4,   LOSS_function: 205.2,   LOSS_E:0.5825,    LOSS_initial: 0.112,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 10.162020206451416
# loss_compared with real:2.38,   miu_train:0.006131,    lossmean:1.481
# Epoch [170/4000], Loss: 1330,   LOSS_function: 200.8,   LOSS_E:0.4572,    LOSS_initial: 0.3156,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 10.808471441268921
# loss_compared with real:1.8464,   miu_train:0.008566,    lossmean:1.366
# Epoch [180/4000], Loss: 1721,   LOSS_function: 579.5,   LOSS_E:0.3796,    LOSS_initial: 0.3297,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 11.43932294845581
# loss_compared with real:1.4596,   miu_train:0.004378,    lossmean:1.195
# Epoch [190/4000], Loss: 903.1,   LOSS_function: 522.6,   LOSS_E:0.2949,    LOSS_initial: 0.08751,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.002,    time: 12.093048810958862
# loss_compared with real:1.1524,   miu_train:0.002558,    lossmean:1.164
# Epoch [200/4000], Loss: 630.6,   LOSS_function: 410.4,   LOSS_E:0.2229,    LOSS_initial: 0.04366,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 12.70923662185669
# loss_compared with real:0.72991,   miu_train:0.00392,    lossmean:0.8742
# Epoch [210/4000], Loss: 549.5,   LOSS_function: 273.1,   LOSS_E:0.2038,    LOSS_initial: 0.06496,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 13.318421363830566
# loss_compared with real:0.48333,   miu_train:0.003478,    lossmean:0.7286
# Epoch [220/4000], Loss: 504.7,   LOSS_function: 279.8,   LOSS_E:0.1837,    LOSS_initial: 0.05046,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 13.907262086868286
# loss_compared with real:0.39996,   miu_train:0.004361,    lossmean:0.6447
# Epoch [230/4000], Loss: 452.3,   LOSS_function: 287.4,   LOSS_E:0.1515,    LOSS_initial: 0.03475,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 14.511443853378296
# loss_compared with real:0.29494,   miu_train:0.003638,    lossmean:0.5628
# Epoch [240/4000], Loss: 466.2,   LOSS_function: 237.9,   LOSS_E:0.1417,    LOSS_initial: 0.05722,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 15.123089790344238
# loss_compared with real:0.30737,   miu_train:0.005362,    lossmean:0.5794
# Epoch [250/4000], Loss: 606.9,   LOSS_function: 473.8,   LOSS_E:0.1105,    LOSS_initial: 0.02963,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 15.724939584732056
# loss_compared with real:0.20908,   miu_train:0.003254,    lossmean:0.4916
# Epoch [260/4000], Loss: 395.6,   LOSS_function: 269,   LOSS_E:0.1146,    LOSS_initial: 0.02694,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 16.300105571746826
# loss_compared with real:0.1885,   miu_train:0.004004,    lossmean:0.4865
# Epoch [270/4000], Loss: 621,   LOSS_function: 512.9,   LOSS_E:0.08836,    LOSS_initial: 0.02427,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 16.91028356552124
# loss_compared with real:0.14295,   miu_train:0.003495,    lossmean:0.3958
# Epoch [280/4000], Loss: 545.3,   LOSS_function: 389.1,   LOSS_E:0.08727,    LOSS_initial: 0.04043,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 17.526517629623413
# loss_compared with real:0.11398,   miu_train:0.003039,    lossmean:0.3895
# Epoch [290/4000], Loss: 458.9,   LOSS_function: 300.2,   LOSS_E:0.07185,    LOSS_initial: 0.04333,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 18.112316370010376
# loss_compared with real:0.10066,   miu_train:0.004366,    lossmean:0.3492
# Epoch [300/4000], Loss: 404.1,   LOSS_function: 297.8,   LOSS_E:0.06435,    LOSS_initial: 0.02683,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 18.714102506637573
# loss_compared with real:0.085303,   miu_train:0.003763,    lossmean:0.3444
# Epoch [310/4000], Loss: 761,   LOSS_function: 553.3,   LOSS_E:0.05561,    LOSS_initial: 0.06181,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 19.374178647994995
# loss_compared with real:0.08411,   miu_train:0.003824,    lossmean:0.3196
# Epoch [320/4000], Loss: 339.1,   LOSS_function: 181.7,   LOSS_E:0.04724,    LOSS_initial: 0.04617,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 19.987662315368652
# loss_compared with real:0.10745,   miu_train:0.004669,    lossmean:0.3089
# Epoch [330/4000], Loss: 1496,   LOSS_function: 961.8,   LOSS_E:0.04061,    LOSS_initial: 0.1726,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 20.59187364578247
# loss_compared with real:0.083919,   miu_train:0.003004,    lossmean:0.3427
# Epoch [340/4000], Loss: 1112,   LOSS_function: 752.5,   LOSS_E:0.03616,    LOSS_initial: 0.1151,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 21.213883638381958
# loss_compared with real:0.2037,   miu_train:0.002691,    lossmean:0.451
# Epoch [350/4000], Loss: 587.4,   LOSS_function: 388.5,   LOSS_E:0.03336,    LOSS_initial: 0.06186,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 21.80296301841736
# loss_compared with real:0.28351,   miu_train:0.004573,    lossmean:0.5135
# Epoch [360/4000], Loss: 713,   LOSS_function: 605,   LOSS_E:0.03577,    LOSS_initial: 0.0312,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 22.426143646240234
# loss_compared with real:0.12739,   miu_train:0.003785,    lossmean:0.4358
# Epoch [370/4000], Loss: 1079,   LOSS_function: 765.5,   LOSS_E:0.02455,    LOSS_initial: 0.1014,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 23.01592469215393
# loss_compared with real:0.099088,   miu_train:0.002743,    lossmean:0.3059
# Epoch [380/4000], Loss: 549.6,   LOSS_function: 354.6,   LOSS_E:0.02521,    LOSS_initial: 0.06162,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 23.62109637260437
# loss_compared with real:0.15031,   miu_train:0.005104,    lossmean:0.4222
# Epoch [390/4000], Loss: 423.4,   LOSS_function: 245.7,   LOSS_E:0.02499,    LOSS_initial: 0.05591,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.001,    time: 24.246306657791138
# loss_compared with real:0.13329,   miu_train:0.005685,    lossmean:0.4115
# Epoch [400/4000], Loss: 584.7,   LOSS_function: 423.9,   LOSS_E:0.02708,    LOSS_initial: 0.05,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 24.874485731124878
# loss_compared with real:0.059248,   miu_train:0.003325,    lossmean:0.2611
# Epoch [410/4000], Loss: 546,   LOSS_function: 336.4,   LOSS_E:0.02792,    LOSS_initial: 0.06617,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 25.48580574989319
# loss_compared with real:0.051603,   miu_train:0.00221,    lossmean:0.2766
# Epoch [420/4000], Loss: 676.5,   LOSS_function: 614.6,   LOSS_E:0.01872,    LOSS_initial: 0.01812,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 26.091562271118164
# loss_compared with real:0.049158,   miu_train:0.003122,    lossmean:0.2568
# Epoch [430/4000], Loss: 604.2,   LOSS_function: 504.6,   LOSS_E:0.02334,    LOSS_initial: 0.03009,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 26.70674753189087
# loss_compared with real:0.056035,   miu_train:0.003553,    lossmean:0.2427
# Epoch [440/4000], Loss: 365.8,   LOSS_function: 241.7,   LOSS_E:0.02042,    LOSS_initial: 0.03863,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 27.31056571006775
# loss_compared with real:0.07014,   miu_train:0.004031,    lossmean:0.2612
# Epoch [450/4000], Loss: 594.7,   LOSS_function: 521.4,   LOSS_E:0.01998,    LOSS_initial: 0.02177,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 27.917542219161987
# loss_compared with real:0.037123,   miu_train:0.003627,    lossmean:0.2257
# Epoch [460/4000], Loss: 246.7,   LOSS_function: 177,   LOSS_E:0.01901,    LOSS_initial: 0.0207,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 28.51540207862854
# loss_compared with real:0.023627,   miu_train:0.003595,    lossmean:0.1714
# Epoch [470/4000], Loss: 604.5,   LOSS_function: 376.9,   LOSS_E:0.02141,    LOSS_initial: 0.07301,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 29.10425066947937
# loss_compared with real:0.029484,   miu_train:0.002876,    lossmean:0.1955
# Epoch [480/4000], Loss: 443.5,   LOSS_function: 81.33,   LOSS_E:0.02412,    LOSS_initial: 0.1175,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 29.730440855026245
# loss_compared with real:0.035266,   miu_train:0.003111,    lossmean:0.1878
# Epoch [490/4000], Loss: 743.7,   LOSS_function: 601,   LOSS_E:0.0202,    LOSS_initial: 0.04487,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 30.363909006118774
# loss_compared with real:0.038221,   miu_train:0.003812,    lossmean:0.1945
# Epoch [500/4000], Loss: 659.1,   LOSS_function: 443.7,   LOSS_E:0.01879,    LOSS_initial: 0.06929,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 30.981131553649902
# loss_compared with real:0.029865,   miu_train:0.003831,    lossmean:0.1876
# Epoch [510/4000], Loss: 287.8,   LOSS_function: 120.7,   LOSS_E:0.01633,    LOSS_initial: 0.05351,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 31.590275287628174
# loss_compared with real:0.050936,   miu_train:0.005696,    lossmean:0.2135
# Epoch [520/4000], Loss: 585.7,   LOSS_function: 475.4,   LOSS_E:0.01249,    LOSS_initial: 0.03511,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 32.18958115577698
# loss_compared with real:0.055422,   miu_train:0.0044,    lossmean:0.257
# Epoch [530/4000], Loss: 849.3,   LOSS_function: 800.7,   LOSS_E:0.01367,    LOSS_initial: 0.0144,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 32.80165958404541
# loss_compared with real:0.034879,   miu_train:0.00295,    lossmean:0.2271
# Epoch [540/4000], Loss: 560,   LOSS_function: 484.7,   LOSS_E:0.01452,    LOSS_initial: 0.02319,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 33.4058358669281
# loss_compared with real:0.030058,   miu_train:0.003708,    lossmean:0.1804
# Epoch [550/4000], Loss: 376,   LOSS_function: 110.4,   LOSS_E:0.01369,    LOSS_initial: 0.08668,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 34.04368734359741
# loss_compared with real:0.034835,   miu_train:0.004427,    lossmean:0.1901
# Epoch [560/4000], Loss: 406.4,   LOSS_function: 321.5,   LOSS_E:0.01193,    LOSS_initial: 0.02672,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 34.66811919212341
# loss_compared with real:0.036281,   miu_train:0.003953,    lossmean:0.1937
# Epoch [570/4000], Loss: 317.1,   LOSS_function: 247.3,   LOSS_E:0.01532,    LOSS_initial: 0.02125,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 35.300986766815186
# loss_compared with real:0.024018,   miu_train:0.00332,    lossmean:0.1943
# Epoch [580/4000], Loss: 467.2,   LOSS_function: 247.7,   LOSS_E:0.01289,    LOSS_initial: 0.07145,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 35.91598129272461
# loss_compared with real:0.028995,   miu_train:0.003241,    lossmean:0.1561
# Epoch [590/4000], Loss: 385.5,   LOSS_function: 337.3,   LOSS_E:0.009573,    LOSS_initial: 0.01481,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.0005,    time: 36.52615809440613
# loss_compared with real:0.028628,   miu_train:0.004279,    lossmean:0.1889
# Epoch [600/4000], Loss: 263.8,   LOSS_function: 197.3,   LOSS_E:0.01126,    LOSS_initial: 0.02064,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 37.16937041282654
# loss_compared with real:0.040856,   miu_train:0.005668,    lossmean:0.2064
# Epoch [610/4000], Loss: 724.9,   LOSS_function: 359.7,   LOSS_E:0.01188,    LOSS_initial: 0.1201,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 37.81206941604614
# loss_compared with real:0.019378,   miu_train:0.002722,    lossmean:0.1571
# Epoch [620/4000], Loss: 191.8,   LOSS_function: 100.3,   LOSS_E:0.009946,    LOSS_initial: 0.02916,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 38.40328311920166
# loss_compared with real:0.03845,   miu_train:0.004512,    lossmean:0.2154
# Epoch [630/4000], Loss: 219.4,   LOSS_function: 118.5,   LOSS_E:0.01061,    LOSS_initial: 0.03222,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 39.01846623420715
# loss_compared with real:0.021678,   miu_train:0.003717,    lossmean:0.1614
# Epoch [640/4000], Loss: 207.6,   LOSS_function: 180.2,   LOSS_E:0.009979,    LOSS_initial: 0.007825,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 39.63879036903381
# loss_compared with real:0.02128,   miu_train:0.004534,    lossmean:0.1603
# Epoch [650/4000], Loss: 200.2,   LOSS_function: 135,   LOSS_E:0.009491,    LOSS_initial: 0.02049,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 40.245590925216675
# loss_compared with real:0.016655,   miu_train:0.003975,    lossmean:0.1608
# Epoch [660/4000], Loss: 393.3,   LOSS_function: 297.2,   LOSS_E:0.008839,    LOSS_initial: 0.03086,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 40.8815803527832
# loss_compared with real:0.023966,   miu_train:0.003894,    lossmean:0.1659
# Epoch [670/4000], Loss: 304.6,   LOSS_function: 265.5,   LOSS_E:0.01012,    LOSS_initial: 0.01167,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 41.516292333602905
# loss_compared with real:0.018752,   miu_train:0.004326,    lossmean:0.1526
# Epoch [680/4000], Loss: 184.6,   LOSS_function: 112.7,   LOSS_E:0.007378,    LOSS_initial: 0.02298,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 42.115203619003296
# loss_compared with real:0.015535,   miu_train:0.004231,    lossmean:0.1318
# Epoch [690/4000], Loss: 690.4,   LOSS_function: 458.8,   LOSS_E:0.01149,    LOSS_initial: 0.07567,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 42.762084007263184
# loss_compared with real:0.010735,   miu_train:0.002994,    lossmean:0.131
# Epoch [700/4000], Loss: 442.3,   LOSS_function: 407.8,   LOSS_E:0.007706,    LOSS_initial: 0.01047,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 43.43458533287048
# loss_compared with real:0.015476,   miu_train:0.003538,    lossmean:0.1582
# Epoch [710/4000], Loss: 269.1,   LOSS_function: 197.7,   LOSS_E:0.006425,    LOSS_initial: 0.02293,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 44.0824191570282
# loss_compared with real:0.023205,   miu_train:0.004264,    lossmean:0.1638
# Epoch [720/4000], Loss: 343.7,   LOSS_function: 144.1,   LOSS_E:0.007695,    LOSS_initial: 0.0655,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 44.69710874557495
# loss_compared with real:0.018846,   miu_train:0.003435,    lossmean:0.1474
# Epoch [730/4000], Loss: 199.7,   LOSS_function: 156.9,   LOSS_E:0.008267,    LOSS_initial: 0.01317,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 45.36873459815979
# loss_compared with real:0.020969,   miu_train:0.004224,    lossmean:0.1525
# Epoch [740/4000], Loss: 246.2,   LOSS_function: 106.7,   LOSS_E:0.008879,    LOSS_initial: 0.04533,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 46.02253794670105
# loss_compared with real:0.019836,   miu_train:0.004086,    lossmean:0.1703
# Epoch [750/4000], Loss: 644.8,   LOSS_function: 539.6,   LOSS_E:0.006829,    LOSS_initial: 0.03414,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 46.685301780700684
# loss_compared with real:0.018218,   miu_train:0.003007,    lossmean:0.1293
# Epoch [760/4000], Loss: 520,   LOSS_function: 490.9,   LOSS_E:0.007078,    LOSS_initial: 0.008757,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 47.321369886398315
# loss_compared with real:0.014172,   miu_train:0.004321,    lossmean:0.1276
# Epoch [770/4000], Loss: 250.2,   LOSS_function: 224.3,   LOSS_E:0.005771,    LOSS_initial: 0.007872,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 47.940547704696655
# loss_compared with real:0.014184,   miu_train:0.004452,    lossmean:0.1106
# Epoch [780/4000], Loss: 435.2,   LOSS_function: 291.8,   LOSS_E:0.008445,    LOSS_initial: 0.04669,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 48.58001375198364
# loss_compared with real:0.0089598,   miu_train:0.002961,    lossmean:0.1188
# Epoch [790/4000], Loss: 178.6,   LOSS_function: 124.5,   LOSS_E:0.00847,    LOSS_initial: 0.01691,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.00025,    time: 49.239354610443115
# loss_compared with real:0.01139,   miu_train:0.003959,    lossmean:0.1262
# Epoch [800/4000], Loss: 305.6,   LOSS_function: 250.9,   LOSS_E:0.007644,    LOSS_initial: 0.01723,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 49.88835096359253
# loss_compared with real:0.0094839,   miu_train:0.00349,    lossmean:0.1072
# Epoch [810/4000], Loss: 329.9,   LOSS_function: 90.18,   LOSS_E:0.007499,    LOSS_initial: 0.0789,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 50.532044887542725
# loss_compared with real:0.0083251,   miu_train:0.003587,    lossmean:0.1127
# Epoch [820/4000], Loss: 519.1,   LOSS_function: 421.6,   LOSS_E:0.008065,    LOSS_initial: 0.03142,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 51.146140813827515
# loss_compared with real:0.011918,   miu_train:0.003858,    lossmean:0.1184
# Epoch [830/4000], Loss: 673.1,   LOSS_function: 609.2,   LOSS_E:0.007244,    LOSS_initial: 0.02033,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 51.801711320877075
# loss_compared with real:0.012692,   miu_train:0.003858,    lossmean:0.1273
# Epoch [840/4000], Loss: 156.1,   LOSS_function: 113.6,   LOSS_E:0.005896,    LOSS_initial: 0.01337,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 52.4559006690979
# loss_compared with real:0.013434,   miu_train:0.00468,    lossmean:0.1283
# Epoch [850/4000], Loss: 583.4,   LOSS_function: 517.4,   LOSS_E:0.007115,    LOSS_initial: 0.02104,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 53.09292483329773
# loss_compared with real:0.01197,   miu_train:0.003547,    lossmean:0.1178
# Epoch [860/4000], Loss: 321.5,   LOSS_function: 115.3,   LOSS_E:0.008465,    LOSS_initial: 0.0676,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 53.741610050201416
# loss_compared with real:0.0093047,   miu_train:0.003124,    lossmean:0.1188
# Epoch [870/4000], Loss: 393.4,   LOSS_function: 326.1,   LOSS_E:0.007068,    LOSS_initial: 0.02149,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 54.37980818748474
# loss_compared with real:0.017228,   miu_train:0.00418,    lossmean:0.1339
# Epoch [880/4000], Loss: 318.2,   LOSS_function: 290.6,   LOSS_E:0.006525,    LOSS_initial: 0.008347,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 55.01149225234985
# loss_compared with real:0.011583,   miu_train:0.003933,    lossmean:0.1295
# Epoch [890/4000], Loss: 672.7,   LOSS_function: 614.4,   LOSS_E:0.006379,    LOSS_initial: 0.01858,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 55.678258419036865
# loss_compared with real:0.012322,   miu_train:0.003819,    lossmean:0.1083
# Epoch [900/4000], Loss: 184.6,   LOSS_function: 112.5,   LOSS_E:0.007871,    LOSS_initial: 0.023,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 56.320749044418335
# loss_compared with real:0.01137,   miu_train:0.004022,    lossmean:0.126
# Epoch [910/4000], Loss: 259.7,   LOSS_function: 210.9,   LOSS_E:0.00654,    LOSS_initial: 0.01538,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 56.966933488845825
# loss_compared with real:0.01629,   miu_train:0.005067,    lossmean:0.1186
# Epoch [920/4000], Loss: 405.3,   LOSS_function: 372.6,   LOSS_E:0.005981,    LOSS_initial: 0.01011,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 57.627336263656616
# loss_compared with real:0.0089769,   miu_train:0.00371,    lossmean:0.1047
# Epoch [930/4000], Loss: 272.9,   LOSS_function: 95.84,   LOSS_E:0.005652,    LOSS_initial: 0.05828,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 58.272518157958984
# loss_compared with real:0.0081672,   miu_train:0.003496,    lossmean:0.1056
# Epoch [940/4000], Loss: 145.2,   LOSS_function: 103.6,   LOSS_E:0.006058,    LOSS_initial: 0.01305,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 58.923869609832764
# loss_compared with real:0.015227,   miu_train:0.00481,    lossmean:0.1199
# Epoch [950/4000], Loss: 421.6,   LOSS_function: 340.1,   LOSS_E:0.006318,    LOSS_initial: 0.02632,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 59.55304980278015
# loss_compared with real:0.016967,   miu_train:0.004695,    lossmean:0.124
# Epoch [960/4000], Loss: 499,   LOSS_function: 442.3,   LOSS_E:0.00661,    LOSS_initial: 0.01803,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 60.17223000526428
# loss_compared with real:0.0082264,   miu_train:0.003467,    lossmean:0.106
# Epoch [970/4000], Loss: 333.4,   LOSS_function: 85.84,   LOSS_E:0.007759,    LOSS_initial: 0.08149,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 60.833516359329224
# loss_compared with real:0.010957,   miu_train:0.00324,    lossmean:0.1097
# Epoch [980/4000], Loss: 164,   LOSS_function: 108.7,   LOSS_E:0.005263,    LOSS_initial: 0.01774,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 61.501508474349976
# loss_compared with real:0.021905,   miu_train:0.005338,    lossmean:0.1451
# Epoch [990/4000], Loss: 389.8,   LOSS_function: 354.7,   LOSS_E:0.00481,    LOSS_initial: 0.01106,
# lamda1:1,    lamda2:400,    lamda3:600,      learn rate:0.000125,    time: 62.160699129104614
# loss_compared with real:0.014171,   miu_train:0.004361,    lossmean:0.1158
# Epoch [1000/4000], Loss: 1027,   LOSS_function: 375.6,   LOSS_E:0.006064,    LOSS_initial: 0.03685,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 62.83883285522461
# loss_compared with real:0.019139,   miu_train:0.004804,    lossmean:0.1291
# Epoch [1010/4000], Loss: 546.5,   LOSS_function: 327.7,   LOSS_E:0.003421,    LOSS_initial: 0.007885,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 63.66709613800049
# loss_compared with real:0.020826,   miu_train:0.005134,    lossmean:0.1221
# Epoch [1020/4000], Loss: 949.9,   LOSS_function: 793.1,   LOSS_E:0.0024,    LOSS_initial: 0.0058,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 64.47533822059631
# loss_compared with real:0.018088,   miu_train:0.004105,    lossmean:0.1479
# Epoch [1030/4000], Loss: 622.8,   LOSS_function: 534.6,   LOSS_E:0.001698,    LOSS_initial: 0.002134,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 65.29548525810242
# loss_compared with real:0.022289,   miu_train:0.005016,    lossmean:0.1558
# Epoch [1040/4000], Loss: 234.6,   LOSS_function: 134.4,   LOSS_E:0.001156,    LOSS_initial: 0.004945,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 66.06835412979126
# loss_compared with real:0.017137,   miu_train:0.00512,    lossmean:0.1394
# Epoch [1050/4000], Loss: 335.2,   LOSS_function: 197.1,   LOSS_E:0.001528,    LOSS_initial: 0.00703,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 66.84735298156738
# loss_compared with real:0.012279,   miu_train:0.004861,    lossmean:0.1125
# Epoch [1060/4000], Loss: 181,   LOSS_function: 91.31,   LOSS_E:0.0009166,    LOSS_initial: 0.00481,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 67.64859700202942
# loss_compared with real:0.012733,   miu_train:0.005209,    lossmean:0.1111
# Epoch [1070/4000], Loss: 256.2,   LOSS_function: 183.6,   LOSS_E:0.0009366,    LOSS_initial: 0.003255,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 68.42256617546082
# loss_compared with real:0.011895,   miu_train:0.005108,    lossmean:0.1074
# Epoch [1080/4000], Loss: 454.8,   LOSS_function: 307,   LOSS_E:0.0008497,    LOSS_initial: 0.01007,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 69.16929316520691
# loss_compared with real:0.012474,   miu_train:0.00484,    lossmean:0.1169
# Epoch [1090/4000], Loss: 146.9,   LOSS_function: 85.05,   LOSS_E:0.0006275,    LOSS_initial: 0.003329,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:6.25e-05,    time: 69.81798982620239
# loss_compared with real:0.011474,   miu_train:0.004905,    lossmean:0.1164
# Epoch [1100/4000], Loss: 648.7,   LOSS_function: 513.9,   LOSS_E:0.0008584,    LOSS_initial: 0.008913,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate

# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:3.125e-05,    time: 87.0748405456543
# loss_compared with real:0.0070998,   miu_train:0.004981,    lossmean:0.08156
# Epoch [1360/4000], Loss: 310.6,   LOSS_function: 280.4,   LOSS_E:0.0004088,    LOSS_initial: 0.001286,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:3.125e-05,    time: 87.73953127861023
# loss_compared with real:0.0069832,   miu_train:0.004921,    lossmean:0.08258
# Epoch [1370/4000], Loss: 213.5,   LOSS_function: 163.8,   LOSS_E:0.0004243,    LOSS_initial: 0.002934,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:3.125e-05,    time: 88.42889261245728
# loss_compared with real:0.007436,   miu_train:0.005046,    lossmean:0.08884
# Epoch [1380/4000], Loss: 687.4,   LOSS_function: 650.7,   LOSS_E:0.0004972,    LOSS_initial: 0.001556,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:3.125e-05,    time: 89.13026165962219
# loss_compared with real:0.0075611,   miu_train:0.005254,    lossmean:0.07918
# Epoch [1390/4000], Loss: 240.5,   LOSS_function: 167.4,   LOSS_E:0.0003785,    LOSS_initial: 0.005114,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:3.125e-05,    time: 89.8024525642395
# loss_compared with real:0.0059203,   miu_train:0.004651,    lossmean:0.0786
# Epoch [1400/4000], Loss: 152.2,   LOSS_function: 124,   LOSS_E:0.0003801,    LOSS_initial: 0.001209,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 90.45914196968079
# loss_compared with real:0.0069097,   miu_train:0.005328,    lossmean:0.08566
# Epoch [1410/4000], Loss: 480.5,   LOSS_function: 436.1,   LOSS_E:0.0005111,    LOSS_initial: 0.002185,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 91.13105964660645
# loss_compared with real:0.0067376,   miu_train:0.004923,    lossmean:0.076
# Epoch [1420/4000], Loss: 274.1,   LOSS_function: 225,   LOSS_E:0.0004744,    LOSS_initial: 0.002718,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 91.82276701927185
# loss_compared with real:0.0070795,   miu_train:0.004943,    lossmean:0.08535
# Epoch [1430/4000], Loss: 152.1,   LOSS_function: 106.5,   LOSS_E:0.0004077,    LOSS_initial: 0.002635,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 92.52708220481873
# loss_compared with real:0.0065327,   miu_train:0.004919,    lossmean:0.08017
# Epoch [1440/4000], Loss: 498.1,   LOSS_function: 456.4,   LOSS_E:0.0003444,    LOSS_initial: 0.002492,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 93.2167797088623
# loss_compared with real:0.0068454,   miu_train:0.004817,    lossmean:0.08029
# Epoch [1450/4000], Loss: 147.9,   LOSS_function: 117.2,   LOSS_E:0.0004963,    LOSS_initial: 0.001047,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 93.90196752548218
# loss_compared with real:0.006724,   miu_train:0.00503,    lossmean:0.08693
# Epoch [1460/4000], Loss: 256.1,   LOSS_function: 226.8,   LOSS_E:0.0004535,    LOSS_initial: 0.001057,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 94.5916690826416
# loss_compared with real:0.0061173,   miu_train:0.005068,    lossmean:0.07423
# Epoch [1470/4000], Loss: 686.4,   LOSS_function: 641.7,   LOSS_E:0.0004153,    LOSS_initial: 0.002514,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate:1.563e-05,    time: 95.25505471229553
# loss_compared with real:0.0062746,   miu_train:0.0049,    lossmean:0.07744
# Epoch [1480/4000], Loss: 629.3,   LOSS_function: 579.3,   LOSS_E:0.0004553,    LOSS_initial: 0.002854,
# lamda1:1,    lamda2:3.739e+04,    lamda3:2303,      learn rate
-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 273.54301166534424
# loss_compared with real:0.011253,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3910/4000], Loss: 327.3,   LOSS_function: 193.9,   LOSS_E:0.0003639,    LOSS_initial: 2.401e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 274.2013554573059
# loss_compared with real:0.011253,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3920/4000], Loss: 423.2,   LOSS_function: 309.3,   LOSS_E:0.00031,    LOSS_initial: 2.403e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 274.86491894721985
# loss_compared with real:0.011253,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3930/4000], Loss: 203.4,   LOSS_function: 128.2,   LOSS_E:0.0002036,    LOSS_initial: 2.405e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 275.5214936733246
# loss_compared with real:0.011253,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3940/4000], Loss: 287.8,   LOSS_function: 204.2,   LOSS_E:0.0002271,    LOSS_initial: 2.399e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 276.17387557029724
# loss_compared with real:0.011253,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3950/4000], Loss: 257,   LOSS_function: 150.7,   LOSS_E:0.0002892,    LOSS_initial: 2.39e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 276.8553900718689
# loss_compared with real:0.011252,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3960/4000], Loss: 261.8,   LOSS_function: 189.1,   LOSS_E:0.0001969,    LOSS_initial: 2.401e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 277.50895500183105
# loss_compared with real:0.011252,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3970/4000], Loss: 979,   LOSS_function: 857.3,   LOSS_E:0.0003314,    LOSS_initial: 2.413e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 278.15892934799194
# loss_compared with real:0.011252,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3980/4000], Loss: 1008,   LOSS_function: 899.3,   LOSS_E:0.0002955,    LOSS_initial: 2.434e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 278.8223822116852
# loss_compared with real:0.011252,   miu_train:0.005525,    lossmean:0.1019
# Epoch [3990/4000], Loss: 921.6,   LOSS_function: 819.7,   LOSS_E:0.0002771,    LOSS_initial: 2.46e-06,
# lamda1:1,    lamda2:3.64e+05,    lamda3:8.293e+04,      learn rate:3.815e-09,    time: 279.47287678718567
# loss_compared with real:0.011251,   miu_train:0.005525,    lossmean:0.1019
# Epoch [4000/4000], Loss: 564.9,   LOSS_function: 452.3,   LOSS_E:0.0002674,    LOSS_initial: 2.477e-06,
# lamda1:1,    lamda2:4.17e+05,    lamda3:8.293e+04,      learn rate:1.907e-09,    time: 280.1562752723694
# loss_compared with real:0.011251,   miu_train:0.005525,    lossmean:0.1019
# net.0.bias Parameter containing:
# tensor([-5.4602e-01, -5.6152e-01, -3.2674e-01, -9.7821e-01, -9.5269e-02,
#         -3.8495e-01,  4.7033e-01, -8.6536e-01,  9.1882e-01,  3.2391e-01,
#          7.7940e-01,  5.4862e-01,  6.5855e-01, -5.5045e-02,  7.0823e-01,
#         -3.4779e-01,  8.7279e-01,  4.1080e-02,  8.3959e-01, -8.0548e-01,
#         -0.0974, -0.0715, -0.0157, -0.0754, -0.0267,  0.0678,  0.0416,  0.0237,
#         -0.0080, -0.0574,  0.0824,  0.0185,  0.0256, -0.0579, -0.0215, -0.0389,
#          0.0152, -0.0591, -0.0709, -0.0476,  0.0329, -0.0584, -0.0812, -0.0249,
#         -0.0176,  0.0076, -0.0627,  0.0014, -0.0243, -0.0264,  0.0785, -0.0159,
#         -0.0246,  0.0522, -0.0130,  0.0422,  0.0186, -0.1050, -0.0069, -0.0653,
#          0.0083,  0.0220, -0.0498, -0.0870,  0.0641,  0.0597,  0.0105,  0.0693,
#         -0.0828, -0.0742,  0.0395, -0.0611, -0.0451,  0.0379, -0.0658, -0.0446,
#          0.0250,  0.0409,  0.0112, -0.0899,  0.0656, -0.0815,  0.0730,  0.0651,
#         -0.0558, -0.0699,  0.0626, -0.0011, -0.0890,  0.0157, -0.0180,  0.0392,
#          0.0513, -0.0530,  0.0635, -0.0842, -0.0448,  0.0278, -0.0011,  0.0545],
#        requires_grad=True)
# net.7.a Parameter containing:
# tensor(0.1569, requires_grad=True)
# net.8.bias Parameter containing:
# tensor([-0.0408,  0.0330,  0.0228], requires_grad=True)

# %%
old_uname='hh.pth'
#保存神经网络
torch.save(u.state_dict(), new_prefix + old_uname[2:])

# %%
file_lists = [loss_list, lpde_list, l0_list, lE_list, lamda1_list, lamda2_list,lamda3_list,l_withoutweight_list, time_list, loss_test_list, lossmean_test_list,miu_train_list]
file_names = ['hh_loss.txt', 'hh_lpde.txt', 'hh_l0.txt', 'hh_lE.txt', 'hh_lamda1.txt','hh_lamda2.txt', 'hh_lamda3.txt', 'hh_l_withoutweight.txt', 'hh_time.txt', 'hh_loss_test.txt', 'hh_lossmean_test.txt','hh_miu_train_list.txt']

for file_list, old_name in zip(file_lists, file_names):
    new_name = new_prefix + old_name[2:]  # 保留原始文件名中的后缀部分
    with open(new_name, 'w') as f:
        for item in file_list:
            f.write("%s\n" % item)

# %%
#计算神经网络的轨迹
output_history= []#想要缩短周期，就调大Bz
for i in range(jump,(n_all+1+jump)):
        # 将当前状态输入神经网络得到下一时刻的状态
        next_state = u.forward(torch.tensor([interval*i]) )#+torch.rand(1) * interval )

        # 记录输出值
        output_history.append(next_state)

import numpy as np
x_coordinates = np.array([x[0].item() for x in output_history])
y_coordinates = np.array([x[1].item() for x in output_history])
z_coordinates = np.array([x[2].item() for x in output_history])

# %%
#绘制轨迹，2维
plt.plot(x_coordinates,y_coordinates,linestyle='--', label='PINN')
plt.plot(x_real_plt, y_real_plt,label='VPA')


plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
# plt.title('PINN results VS classic results')
plt.show()

# %%
file_lists = [x_coordinates, y_coordinates, z_coordinates]
file_names = ['hh_outputx.txt', 'hh_outputy.txt', 'hh_outputz.txt']

for file_list, old_name in zip(file_lists, file_names):
    new_name = new_prefix + old_name[2:]  # 保留原始文件名中的后缀部分
    with open(new_name, 'w') as f:
        for item in file_list:
            f.write("%s\n" % item)

# %%
# 绘制轨迹 3维
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x_plt[::int(n_all/50)], y_plt[::int(n_all/50)] ,z_plt[::int(n_all/50)],color='red',label='VPA')
#ax.plot(x_coordinates[::int(n_all/100)],y_coordinates[::int(n_all/100)],z_coordinates[::int(n_all/100)],label='neural network')
ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# ax.set_title('Particle Motion in Electromagnetic Field')
plt.show()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax.plot(x_plt[::int(n_all/100)], y_plt[::int(n_all/100)] ,z_plt[::int(n_all/100)],label='classic computation')
ax.plot(x_coordinates[::int(n_all/50)],y_coordinates[::int(n_all/50)],z_coordinates[::int(n_all/50)],label='PINN')
ax.legend()
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# ax.set_title('Particle Motion in Electromagnetic Field')
plt.show()

# %%
#绘制各loss成分随训练次数epoch变化图
epoch_total = len(loss_list)
epoch_array = np.array(range(0, epoch_total * n_epoch, n_epoch))

plt.figure(figsize=(10, 6))  # 设置图像大小为原始大小的1.3倍，10英寸6英寸
plt.plot(epoch_array,lpde_list,label=r'$L_{r}(\theta)$')
#plt.plot(epoch_array,lmiu_list, label='Loss of μ ')
plt.plot(epoch_array,lE_list, label=r'$L_{E}(\theta)$')
plt.plot(epoch_array,l0_list, label=r'$L_{ic}(\theta)$')
plt.plot(epoch_array,loss_list, label=r'$L(\theta)$')
plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
# plt.title(r'$Convergence\;of\;rel.\;L^2\;error\;during\;training\;process$')
# 添加图例并设置字体大小，并将其放在图形外部
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))


plt.tight_layout()# 自动调整布局，确保图像完整显示
plt.show()


plt.plot(epoch_array,lamda1_list,label=r'$λ_{r}(\theta)$')
plt.plot(epoch_array,lamda2_list,label=r'$λ_{E}(\theta)$')
plt.plot(epoch_array,lamda3_list,label=r'$λ_{ic}(\theta)$')
#plt.plot(epoch_array,lamda4_list,label='λ for loss of μ')
plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Adaptive weights', fontsize='x-large')
# plt.title('Adaptive weights during training process')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))

plt.show()#绘图

plt.plot(epoch_array,loss_test_list)
plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
# plt.title('Geometric difference of position from classic data during training process')

plt.show()#绘图

plt.plot(epoch_array,lossmean_test_list)
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Summed Error', fontsize='x-large')
# plt.title('Arithmetic difference of position from classic data during training process')

plt.show()#绘图

# %%
#绘制损失函数在各时刻的分布
lpde_tl_list=[]

lE_tl_list=[]

loss_test_tl_list=[]

lossmean_test_tl_list=[]
for i in range(jump,(n_all+1+jump),10):
    t_tl = torch.tensor([i*interval]).view(-1, 1).requires_grad_(True)#tl:trainloss
    x_tl = u(t_tl)[:,0]
    y_tl = u(t_tl)[:,1]
    z_tl = u(t_tl)[:,2]
    vx_tl = gradients(x_tl, t_tl, 1)
    vy_tl = gradients(y_tl, t_tl, 1)
    vz_tl = gradients(z_tl, t_tl, 1)
    lpde1_tl = loss(gradients(vx_tl, t_tl, 1), q_over_m*(Ex + vy_tl * Bz(x_tl,y_tl,z_tl) - vz_tl * By(x_tl,y_tl,z_tl)))
    lpde2_tl = loss(gradients(vy_tl, t_tl, 1), q_over_m*(Ey + vz_tl * Bx(x_tl,y_tl,z_tl) - vx_tl * Bz(x_tl,y_tl,z_tl)))
    lpde3_tl = loss(gradients(vz_tl, t_tl, 1), q_over_m*(Ez + vx_tl * By(x_tl,y_tl,z_tl) - vy_tl * Bx(x_tl,y_tl,z_tl)))
    lE_tl = loss((vx_tl**2+vy_tl**2+vz_tl**2)**0.5,tensortarget)
    lpde_tl = lpde1_tl + lpde2_tl + lpde3_tl
    x_real_tl = x_real_plt[i-jump]
    y_real_tl = y_real_plt[i-jump]
    z_real_tl = z_real_plt[i-jump]
    vx_real_tl = vx_real_plt[i-jump]
    vy_real_tl = vy_real_plt[i-jump]
    vz_real_tl = vz_real_plt[i-jump]
    loss_test_tl = loss(x_tl,x_real_tl)+loss(y_tl,y_real_tl)+loss(z_tl,z_real_tl)
    lossmean_test_tl = (x_tl-x_real_tl+y_tl-y_real_tl+z_tl-z_real_tl)
    lpde_tl_list.append(lpde_tl.item())
    lE_tl_list.append(lE_tl.item())
    loss_test_tl_list.append(loss_test_tl.item())
    lossmean_test_tl_list.append(lossmean_test_tl.item())
tl_array = np.arange(jump*interval, (n_all+1+jump)*interval, 10*interval)
# Out:
# C:\Users\hxm\anaconda3\lib\site-packages\torch\nn\modules\loss.py:536: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
plt.figure(figsize=(10, 6))  # 设置图像大小为原始大小的1.3倍，10英寸6英寸
plt.plot(tl_array,lpde_tl_list,label=r'$L_{r}(\theta)$')
plt.plot(tl_array,lE_tl_list,label=r'$L_{E}(\theta)$')
plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('t/μs', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
# plt.title('Loss of ODEs and loss of E from real data during motion process')
plt.legend(fontsize='x-large', loc='upper right')

plt.tight_layout()# 自动调整布局，确保图像完整显示
plt.show()

plt.plot(tl_array,loss_test_tl_list)
plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('t/μs', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
# plt.title('Geometric differences of position from real data during motion process')

plt.show()#绘图

plt.plot(tl_array,lossmean_test_tl_list)
plt.xlabel('t/μs', fontsize='x-large')
plt.ylabel('Summed Error', fontsize='x-large')
# plt.title('Arithmetic differences of position from real data during motion process')

plt.show()#绘图

# %%
file_lists = [lpde_tl_list,  lE_tl_list,  loss_test_tl_list, lossmean_test_tl_list]
file_names = ['hh_lpde_tl_list.txt', 'hh_lE_tl_list.txt',  'hh_loss_test_tl_list.txt', 'hh_lossmean_test_tl_list.txt']

for file_list, old_name in zip(file_lists, file_names):
    new_name = new_prefix + old_name[2:]  # 保留原始文件名中的后缀部分
    with open(new_name, 'w') as f:
        for item in file_list:
            f.write("%s\n" % item)
