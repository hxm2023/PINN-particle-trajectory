# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import torch.nn as nn
import torch.optim as optim
import numpy as np
import math

# %%
#短固的batch size。

# %%
interval=4.147267104135095e-4
tl_array = np.arange(0, (50000+1)*interval, 20*interval)

# %%
with open('8.6.longsui_lpde_tl_list.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.6.longsui_lE_tl_list.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
plt.figure(figsize=(10, 6))  # 设置图像大小为原始大小的1.3倍，10英寸6英寸
plt.plot(tl_array,data_list1,label=r'$L_{r}(\theta,t_i)$')
plt.plot(tl_array,data_list2,label=r'$L_{E}(\theta,t_i)$')
plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('t/μs', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
# plt.title('Loss of ODEs and loss of E from real data during motion process')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))

# %%
#先画短训练batch选择图，短固loss


# 从第一个文件中读取数据并写成列表形式
with open('8.3.duangu-10_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duangu-20_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.3.duangu-50_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.3.duangu_loss.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.3.duangu-250_loss.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]
with open('8.3.duangu-500_loss.txt', 'r') as file6:
    data_list6 = [float(line.strip()) for line in file6.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=250')
plt.plot(epoch_array,data_list6, label='batch_size=500')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]
data_list6=[]

# %%
with open('8.2.longsuifail_lamda1.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.2.longsuifail_lamda3.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]



epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 50, 50))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label=r'$\lambda_{r}$')
plt.plot(epoch_array,data_list2, label=r'$\lambda_{ic}$')


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Adaptive Weights', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.duangu-10_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duangu-20_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.3.duangu-50_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.3.duangu_loss_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.3.duangu-250_loss_test.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]
with open('8.3.duangu-500_loss_test.txt', 'r') as file6:
    data_list6 = [float(line.strip()) for line in file6.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=250')
plt.plot(epoch_array,data_list6, label='batch_size=500')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]
data_list6=[]

# %%
#先画短训练batch选择图


# 从第一个文件中读取数据并写成列表形式
with open('8.3.duansui-10_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duansui-20_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.3.duansui-50_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.3.duansui_loss.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.3.duansui-250_loss.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]
with open('8.3.duansui-500_loss.txt', 'r') as file6:
    data_list6 = [float(line.strip()) for line in file6.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=250')
plt.plot(epoch_array,data_list6, label='batch_size=500')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]
data_list6=[]

# %%
#先画短训练batch选择图
#这里
# 从第一个文件中读取数据并写成列表形式
with open('8.3.duangu_lpde.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()[-1000:]]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duangu_l0.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()[-1000:]]
with open('8.2.duansui-weight_lpde.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()[-1000:]]
with open('8.2.duansui-weight_l0.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()[-1000:]]



epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
fig, ax = plt.subplots(1, 2, figsize=(12, 4))  # figsize 调整两张图的总大小

# 第一张图
ax[0].plot(epoch_array, data_list1, label=r'$λ_{r}(\theta)$')
ax[0].plot(epoch_array, data_list2, label=r'$λ_{ic}(\theta)$')
ax[0].set_yscale('log')  # 设置纵轴为对数刻度
ax[0].set_xlabel('Epoch', fontsize='x-large')
ax[0].set_ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
ax[0].legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))

# 第二张图
ax[1].plot(epoch_array, data_list3, label=r'$λ_{r}(\theta)$')
ax[1].plot(epoch_array, data_list4, label=r'$λ_{ic}(\theta)$')
ax[1].set_yscale('log')  # 设置纵轴为对数刻度
ax[1].set_xlabel('Epoch', fontsize='x-large')
ax[1].set_ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
ax[1].legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))

# 自动调整布局，防止标签重叠
plt.tight_layout()

# 显示图像
plt.show()

data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.duansui-10_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duansui-20_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.3.duansui-50_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.3.duansui_loss_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.3.duansui-250_loss_test.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]
with open('8.3.duansui-500_loss_test.txt', 'r') as file6:
    data_list6 = [float(line.strip()) for line in file6.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=250')
plt.plot(epoch_array,data_list6, label='batch_size=500')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]
data_list6=[]

# %%
#短固的消融实验

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.duangu_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duangu-weight_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.3.duangu-activation_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.2.duangu_loss.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]



epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list4, label='ELF')
plt.plot(epoch_array,data_list1, label='Plain')#energy loss function
plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.duansui_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duansui-weight_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.3.duansui-activation_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.2.duansui_loss.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list4, label='ELF')
plt.plot(epoch_array,data_list1, label='Plain')#energy loss function
plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.duangu_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
    data_list1 = data_list1[-1000:]


# 从第二个文件中读取数据并写成列表形式
with open('8.2.duangu-weight_loss_test.txt', 'r') as file2:#其实是8.3！
    data_list2 = [float(line.strip()) for line in file2.readlines()]
    data_list2 = data_list2[-1000:]
with open('8.3.duangu-activation_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
    data_list3 = data_list3[-1000:]
with open('8.2.duangu_loss_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
    data_list4 = data_list4[-1000:]



epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='Plain')#energy loss function
plt.plot(epoch_array,data_list4, label='ELF')

plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper right')
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.duansui_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.3.duansui-weight_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.3.duansui-activation_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.2.duansui_loss_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]



epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list4, label='ELF')
plt.plot(epoch_array,data_list1, label='Plain')#energy loss function
plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
#长训的batch size

# %%
#先画短训练batch选择图，短固loss


# 从第一个文件中读取数据并写成列表形式
with open('8.2.changgu-3_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.2.changgu-5_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.2.changgu-10_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.2.changgu.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.2.changgu-200_loss.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=200')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]

# %%
#先画短训练batch选择图，短固loss


# 从第一个文件中读取数据并写成列表形式
with open('8.2.changsui-3_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.2.changsui-5_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.2.changsui-10_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.2.changsui.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.2.changsui-200_loss.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=200')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]

# %%
#先画短训练batch选择图，短固loss


# 从第一个文件中读取数据并写成列表形式
with open('8.2.changgu-3_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.2.changgu-5_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.2.changgu-10_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.2.changgu_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.2.changgu-200_loss_test.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=200')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]

# %%
#先画短训练batch选择图，短固loss


# 从第一个文件中读取数据并写成列表形式
with open('8.2.changsui-3_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.2.changsui-5_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.2.changsui-10_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.2.changsui_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
with open('8.2.changsui-200_loss_test.txt', 'r') as file5:
    data_list5 = [float(line.strip()) for line in file5.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list1, label='batch_size=10')
plt.plot(epoch_array,data_list2, label='batch_size=20')
plt.plot(epoch_array,data_list3, label='batch_size=50')
plt.plot(epoch_array,data_list4, label='batch_size=100')
plt.plot(epoch_array,data_list5, label='batch_size=200')

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]
data_list5=[]

# %%
#长训的消融实验

# %%
len(data_list3)
# Out:
# 121

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.changsui_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
    data_list1=data_list1[:400]

# 从第二个文件中读取数据并写成列表形式
with open('8.2.changsui-weight_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
    data_list2=data_list2[:400]
with open('8.2.changsui-activation_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
    data_list3=data_list3[:400]
with open('8.2.changsui_loss.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
    data_list4=data_list4[:400]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list4, label='Plain')
plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function
plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.3.changsui_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
    data_list1=data_list1[:400]

# 从第二个文件中读取数据并写成列表形式
with open('8.2.changsui-weight_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
    data_list2=data_list2[:400]
with open('8.2.changsui-activation_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
    data_list3=data_list3[:400]
with open('8.2.changsui_loss_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]
    data_list4=data_list4[:400]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list4, label='Plain')
plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function
plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
#多初态的消融实验

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.8.3.changsui_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
# 从第二个文件中读取数据并写成列表形式
with open('8.8.changsui-weight_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.8.changsui-activation_loss.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.8.changsui_loss.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list4, label='Plain')
plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function
plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.8.3.changsui_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]

# 从第二个文件中读取数据并写成列表形式
with open('8.8.changsui-weight_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]
with open('8.8.changsui-activation_loss_test.txt', 'r') as file3:
    data_list3 = [float(line.strip()) for line in file3.readlines()]
with open('8.8.changsui_loss_test.txt', 'r') as file4:
    data_list4 = [float(line.strip()) for line in file4.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list4, label='Plain')
plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function
plt.plot(epoch_array,data_list2, label='No Adaptive Weights')
plt.plot(epoch_array,data_list3, label='No AAF')#自适应激活函数


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
data_list3=[]
data_list4=[]

# %%
#无速度信息的ELF消融实验

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.6.3.changsui_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
# 从第二个文件中读取数据并写成列表形式
with open('8.6.changsui_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list2, label='Plain')
plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.6.3.changsui_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
# 从第二个文件中读取数据并写成列表形式
with open('8.6.changsui_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list2, label='Plain')

plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function

plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.6.3.longsui_loss.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
# 从第二个文件中读取数据并写成列表形式
with open('8.6.longsui_loss.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 100, 100))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list2, label='Plain')
plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel(r'$Rel.\;L^2\;Error$', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]

# %%
# 从第一个文件中读取数据并写成列表形式
with open('8.6.3.longsui_loss_test.txt', 'r') as file1:
    data_list1 = [float(line.strip()) for line in file1.readlines()]
# 从第二个文件中读取数据并写成列表形式
with open('8.6.longsui_loss_test.txt', 'r') as file2:
    data_list2 = [float(line.strip()) for line in file2.readlines()]


epoch_total = len(data_list2)
epoch_array = np.array(range(0, epoch_total * 10, 10))
# 绘制图形
plt.figure(figsize=(10, 6))
plt.plot(epoch_array,data_list2, label='Plain')
plt.plot(epoch_array,data_list1, label='No ELF')#energy loss function


plt.yscale('log')  # 设置纵轴为对数刻度
plt.xlabel('Epoch', fontsize='x-large')
plt.ylabel('Squared Euclidean Error', fontsize='x-large')
plt.legend(fontsize='x-large', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
data_list1=[]
data_list2=[]
